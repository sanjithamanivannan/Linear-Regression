# %% [markdown]
# ### Import the libraries

# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import the dataset

# %%
dataset = pd.read_csv('WildBlueberryPollinationSimulationData.csv')

# %%
dataset
# Out:
#      Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0       0       37.5     0.750    0.250    0.250  0.250              86.0
# 1       1       37.5     0.750    0.250    0.250  0.250              86.0
# 2       2       37.5     0.750    0.250    0.250  0.250              94.6
# 3       3       37.5     0.750    0.250    0.250  0.250              94.6
# 4       4       37.5     0.750    0.250    0.250  0.250              86.0
# ..    ...        ...       ...      ...      ...    ...               ...
# 772   772       10.0     0.537    0.117    0.409  0.058              86.0
# 773   773       40.0     0.537    0.117    0.409  0.058              86.0
# 774   774       20.0     0.537    0.117    0.409  0.058              86.0
# 775   775       20.0     0.537    0.117    0.409  0.058              89.0
# 776   776       20.0     0.537    0.117    0.409  0.058              89.0
#
#      MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# ...

# %% [markdown]
# ### Basic information about the dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row#                  777 non-null    int64
#  1   clonesize             777 non-null    float64
#  2   honeybee              777 non-null    float64
#  3   bumbles               777 non-null    float64
#  4   andrena               777 non-null    float64
#  5   osmia                 777 non-null    float64
#  6   MaxOfUpperTRange      777 non-null    float64
#  7   MinOfUpperTRange      777 non-null    float64
#  8   AverageOfUpperTRange  777 non-null    float64
#  9   MaxOfLowerTRange      777 non-null    float64
#  10  MinOfLowerTRange      777 non-null    float64
#  11  AverageOfLowerTRange  777 non-null    float64
#  12  RainingDays           777 non-null    float64
#  13  AverageRainingDays    777 non-null    float64
# ...

# %%
dataset.describe()
# Out:
#              Row#   clonesize    honeybee     bumbles     andrena       osmia  \
# count  777.000000  777.000000  777.000000  777.000000  777.000000  777.000000
# mean   388.000000   18.767696    0.417133    0.282389    0.468817    0.562062
# std    224.444871    6.999063    0.978904    0.066343    0.161052    0.169119
# min      0.000000   10.000000    0.000000    0.000000    0.000000    0.000000
# 25%    194.000000   12.500000    0.250000    0.250000    0.380000    0.500000
# 50%    388.000000   12.500000    0.250000    0.250000    0.500000    0.630000
# 75%    582.000000   25.000000    0.500000    0.380000    0.630000    0.750000
# max    776.000000   40.000000   18.430000    0.585000    0.750000    0.750000
#
#        MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count        777.000000        777.000000            777.000000
# mean          82.277091         49.700515             68.723037
# std            9.193745          5.595769              7.676984
# ...

# %%
dataset.shape
# Out:
# (777, 18)

# %%
dataset.head()
# Out:
#    Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0     0       37.5      0.75     0.25     0.25   0.25              86.0
# 1     1       37.5      0.75     0.25     0.25   0.25              86.0
# 2     2       37.5      0.75     0.25     0.25   0.25              94.6
# 3     3       37.5      0.75     0.25     0.25   0.25              94.6
# 4     4       37.5      0.75     0.25     0.25   0.25              86.0
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              52.0                  71.9              62.0              30.0
# 2              57.2                  79.0              68.2              33.0
# 3              57.2                  79.0              68.2              33.0
# 4              52.0                  71.9              62.0              30.0
#
# ...

# %% [markdown]
# ### Correlation matrix of the dataset
# A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables.

# %%
dataset.corr()
# Out:
#                           Row#  clonesize  honeybee   bumbles   andrena  \
# Row#                  1.000000   0.438706  0.192404  0.331999  0.446898
# clonesize             0.438706   1.000000  0.119745  0.004807 -0.008451
# honeybee              0.192404   0.119745  1.000000 -0.233954 -0.125913
# bumbles               0.331999   0.004807 -0.233954  1.000000  0.010758
# andrena               0.446898  -0.008451 -0.125913  0.010758  1.000000
# osmia                 0.288531  -0.139049 -0.189058  0.293665  0.387379
# MaxOfUpperTRange     -0.018204   0.034157  0.026359 -0.022863 -0.026497
# MinOfUpperTRange     -0.029893   0.032854  0.025467 -0.005801 -0.023887
# AverageOfUpperTRange -0.023144   0.033752  0.026365 -0.015821 -0.025578
# MaxOfLowerTRange     -0.016947   0.034295  0.026477 -0.024662 -0.026775
# MinOfLowerTRange     -0.022430   0.033768  0.026104 -0.016801 -0.025623
# AverageOfLowerTRange -0.024338   0.033566  0.025647 -0.013985 -0.025115
# ...

# %% [markdown]
# The correlation matrix shows a high correlation of '0.984081' between the columns 'fruitset' and 'yield'.
#
# Hence, the 'fruitset' column has been chosen to predict the yield by using Linear Regression

# %% [markdown]
# ### Dropping other columns

# %%
dataset = dataset.drop(['Row#','clonesize','honeybee','bumbles','andrena','osmia','MaxOfUpperTRange','MinOfUpperTRange','AverageOfUpperTRange','MaxOfLowerTRange','MinOfLowerTRange','AverageOfLowerTRange','RainingDays','AverageRainingDays','fruitmass','seeds'],axis = 1)

# %%
dataset
# Out:
#      fruitset        yield
# 0    0.410652  3813.165795
# 1    0.444254  4947.605663
# 2    0.383787  3866.798965
# 3    0.407564  4303.943030
# 4    0.354413  3436.493543
# ..        ...          ...
# 772  0.486815  5333.873335
# 773  0.342841  3373.436842
# 774  0.404617  4203.027624
# 775  0.401538  4166.299735
# 776  0.384646  3943.131681
#
# [777 rows x 2 columns]

# %% [markdown]
# ### Heatmap
# Visual representation of the correlation between 'fruitset' and 'yield' using heatmap

# %%
plt.figure(figsize=(10,5))
c=dataset.corr()
sn.heatmap(c,cmap='BrBG',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Slicing the dataset

# %%
x = dataset.iloc[:,0]

# %%
x
# Out:
# 0      0.410652
# 1      0.444254
# 2      0.383787
# 3      0.407564
# 4      0.354413
#          ...
# 772    0.486815
# 773    0.342841
# 774    0.404617
# 775    0.401538
# 776    0.384646
# Name: fruitset, Length: 777, dtype: float64

# %%
x.shape
# Out:
# (777,)

# %%
x = dataset.iloc[:,0].values.reshape(-1,1)

# %%
x.shape
# Out:
# (777, 1)

# %%
y = dataset.iloc[:,-1].values.reshape(-1,1)

# %%
y.shape
# Out:
# (777, 1)

# %%
y
# Out:
# array([[3813.165795],
#        [4947.605663],
#        [3866.798965],
#        [4303.94303 ],
#        [3436.493543],
#        [2825.003738],
#        [2625.269164],
#        [2379.905214],
#        [4234.868585],
#        [5356.871861],
#        [4057.555205],
#        [3941.255122],
#        [4768.594369],
#        [3720.711588],
#        [3900.344042],
#        [3387.785165],
#        [2688.028831],
#        [2508.375673],
#        [1945.530615],
#        [4310.625398],
#        [4830.959809],
#        [3911.422247],
#        [4051.551293],
#        [3837.512961],
#        [3269.271761],
#        [4503.161856],
#        [5126.993178],
#        [4248.355054],
#        [4476.811464],
#        [3662.183125],
#        [2988.05944 ],
#        [3049.260316],
#        [2384.728916],
#        [4898.835857],
#        [5831.7066  ],
#        [4334.841218],
#        [5246.521458],
#        [4356.945873],
#        [3822.981667],
#        [3182.698648],
#        [4870.625368],
# ...

# %% [markdown]
# ### Scatter plot

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### Divide the dataset into training and test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
x_train.shape
# Out:
# (621, 1)

# %%
x_test.shape
# Out:
# (156, 1)

# %%
y_train.shape
# Out:
# (621, 1)

# %%
y_test.shape
# Out:
# (156, 1)

# %% [markdown]
# ### Performing Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Predicting the yield

# %%
y_pred = lm.predict(x_test)

# %%
y_pred
# Out:
# array([[6919.39796196],
#        [4494.25125046],
#        [6644.69922092],
#        [3986.82254521],
#        [4349.39934873],
#        [6768.36920768],
#        [5398.36546773],
#        [7554.76705524],
#        [7651.60250921],
#        [4878.96230634],
#        [2883.81540201],
#        [6516.0481496 ],
#        [6510.41143646],
#        [4325.75882657],
#        [7114.87536798],
#        [6521.56104413],
#        [6549.96630347],
#        [7856.71349911],
#        [6914.34776155],
#        [4057.03166868],
#        [6642.07633786],
#        [7791.63901002],
#        [6730.5831971 ],
#        [6395.97434932],
#        [4355.46972868],
#        [6375.56547945],
#        [5453.58474634],
#        [6212.00761596],
#        [4892.94995453],
#        [6167.20542421],
#        [4729.60367874],
#        [7896.91162626],
#        [5331.94799589],
#        [6839.02483567],
#        [8370.54261084],
#        [5442.85159354],
#        [7025.39079759],
#        [6327.65107981],
# ...

# %% [markdown]
# ### Checking the prediction

# %%
check = pd.DataFrame(x_test,columns = ['Fruitset'])

# %%
check['Actual Yield'] = y_test

# %%
check['Predicted Yield'] = y_pred

# %%
check
# Out:
#      Fruitset  Actual Yield  Predicted Yield
# 0    0.556295   6795.881873      6919.397962
# 1    0.411591   4357.822918      4494.251250
# 2    0.539904   7293.536170      6644.699221
# 3    0.381314   3900.344042      3986.822545
# 4    0.402948   4387.741853      4349.399349
# ..        ...           ...              ...
# 151  0.631790   8284.854610      8184.656086
# 152  0.496826   5700.243243      5922.737530
# 153  0.527724   6920.084268      6440.573266
# 154  0.589306   7560.205645      7472.645620
# 155  0.600087   7835.767792      7653.324104
#
# [156 rows x 3 columns]

# %% [markdown]
# ### Visualizing the regressor line

# %%
plt.scatter(x,y,color = 'orange')
plt.plot(x_test,y_pred,color = 'red')
plt.show()

# %%
plt.scatter(x_test,y_test,color = 'blue')
plt.plot(x_test,y_pred,color = 'red')
plt.show()

# %% [markdown]
# The wild blueberry yield has been predicted by using Linear regression
